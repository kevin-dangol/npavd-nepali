# %%
import os
import shutil
import random
from pathlib import Path
import cv2
from ultralytics import YOLO

# %%
# 1. Define paths
BASE_PATH = Path('D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets')
OUTPUT_PATH = BASE_PATH / 'combined_dataset'

# Number Plate Dataset paths
NP_IMAGES = [
    BASE_PATH / 'number plates/normal_imgs',
    BASE_PATH / 'number plates/wide_imgs',
    BASE_PATH / 'number plates/zoomed_imgs'
]
NP_LABELS = [
    BASE_PATH / 'number plates/normal_number_plate_labels',
    BASE_PATH / 'number plates/wide_number_plate_labels',
    BASE_PATH / 'number plates/zoomed_number_plate_labels'
]

# Vehicle Dataset paths
VEHICLE_IMAGES = [
    BASE_PATH / 'vehicles/wide_imgs',
    BASE_PATH / 'vehicles/all_normal_vehicle_dataset_with_labels/car/images',
    BASE_PATH / 'vehicles/all_normal_vehicle_dataset_with_labels/bikes/images',
    BASE_PATH / 'vehicles/all_normal_vehicle_dataset_with_labels/scooter/images'
]
VEHICLE_LABELS = [
    BASE_PATH / 'vehicles/wide_vehicle_detection_labels',
    BASE_PATH / 'vehicles/all_normal_vehicle_dataset_with_labels/car/labels',
    BASE_PATH / 'vehicles/all_normal_vehicle_dataset_with_labels/bikes/labels',
    BASE_PATH / 'vehicles/all_normal_vehicle_dataset_with_labels/scooter/labels'
]

# %%
# 2. Create combined dataset structure
def create_dataset_structure():
    for folder in ['images/train', 'images/val', 'labels/train', 'labels/val']:
        (OUTPUT_PATH / folder).mkdir(parents=True, exist_ok=True)

# %%
# 3. Merge datasets and split
def merge_and_split_datasets(train_split=0.8):
    all_images = []
    all_labels = []

    for img_dir, lbl_dir in zip(NP_IMAGES, NP_LABELS):
        for img in img_dir.glob('*.jpg'):
            label_file = lbl_dir / f"{img.stem}.txt"
            if label_file.exists():
                all_images.append(img)
                all_labels.append(label_file)

    for img_dir, lbl_dir in zip(VEHICLE_IMAGES, VEHICLE_LABELS):
        for img in img_dir.glob('*.jpg'):
            label_file = lbl_dir / f"{img.stem}.txt"
            if label_file.exists():
                all_images.append(img)
                all_labels.append(label_file)

    combined = list(zip(all_images, all_labels))
    random.shuffle(combined)
    all_images, all_labels = zip(*combined)
    
    split_idx = int(len(all_images) * train_split)
    train_images, val_images = all_images[:split_idx], all_images[split_idx:]
    train_labels, val_labels = all_labels[:split_idx], all_labels[split_idx:]

    return train_images, train_labels, val_images, val_labels

# %%
# 4. Copy files and update labels
def copy_files(images, labels, split_type):
    class_mapping = {'number_plate': 0, 'car': 1, 'bike': 2, 'scooter': 3}
    
    for img, lbl in zip(images, labels):
        shutil.copy(img, OUTPUT_PATH / f'images/{split_type}/{img.name}')
        
        with open(lbl, 'r') as f:
            lines = f.readlines()
        
        with open(OUTPUT_PATH / f'labels/{split_type}/{lbl.name}', 'w') as f:
            for line in lines:
                parts = line.strip().split()
                if parts:
                    class_name = next((k for k, v in class_mapping.items() if v == int(parts[0])), None)
                    if class_name:
                        parts[0] = str(class_mapping[class_name])
                        f.write(' '.join(parts) + '\n')

# %%
# 5. Create data.yaml
def create_data_yaml():
    yaml_content = f"""
path: {OUTPUT_PATH}
train: images/train
val: images/val
nc: 4
names: ['number_plate', 'car', 'bike', 'scooter']
    """
    with open(OUTPUT_PATH / 'data.yaml', 'w') as f:
        f.write(yaml_content)

# %%
# 6. Main dataset preparation function
def prepare_dataset():
    create_dataset_structure()
    train_img, train_lbl, val_img, val_lbl = merge_and_split_datasets()
    copy_files(train_img, train_lbl, 'train')
    copy_files(val_img, val_lbl, 'val')
    create_data_yaml()
    print("Dataset preparation completed!")

# %%
# 7. Training and Export
def train_and_export_model():
    model = YOLO('yolov8n.pt')  # Nano version
    
    # Train the model
    model.train(
        data=str(OUTPUT_PATH / 'data.yaml'),
        epochs=100,
        batch=16,
        imgsz=640,
        device=0,
        patience=50,
        augment=True,
        project='runs/train',
        name='nepali_detection',
        exist_ok=True
    )
    
    # Save PyTorch model
    model.save('best_nepali_detection.pt')
    
    # Export to ONNX
    model.export(format='onnx', imgsz=640, dynamic=False)
    print("Model exported to best_nepali_detection.onnx")
    
    return model

def export_model():
    
    model = 'D:/IIMS/sem 3/Computer Vision And Natural Language Processing/Python/Group_project/best_nepali_detection.pt'
    return model

# %%
# 8. Inference functions
def detect_from_image(model, image_path, output_dir="output"):
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    
    results = model(image_path)
    annotated_img = results[0].plot()
    output_file = output_path / f"detected_{Path(image_path).name}"
    cv2.imwrite(str(output_file), annotated_img)
    print(f"Detected image saved to: {output_file}")
    
    cv2.imshow('Detection Result', annotated_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    return results

def detect_from_video(model, video_path, output_dir="output"):
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    output_file = output_path / f"detected_{Path(video_path).stem}.mp4"
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(str(output_file), fourcc, fps, (frame_width, frame_height))
    
    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        results = model(frame)
        annotated_frame = results[0].plot()
        out.write(annotated_frame)
        
        frame_count += 1
        if frame_count % 30 == 0:
            print(f"Processed {frame_count} frames")
    
    cap.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"Detected video saved to: {output_file}")

# %%
# Main execution
if __name__ == "__main__":
    # Prepare dataset
    prepare_dataset()
    
    # Train and export model
    trained_model = train_and_export_model()
    
    # Example inference
    test_image = "D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets/test/test.jpeg"
    test_video = "D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets/test/test.mp4"
    
    detect_from_image(trained_model, test_image)
    detect_from_video(trained_model, test_video)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      12 test_image = "D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets/test/test.jpeg"
#      13 test_video = "D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets/test/test.mp4"
# ---> 15 detect_from_image(trained_model, test_image)
#      16 detect_from_video(trained_model, test_video)
#
# Cell In[2], line 3, in detect_from_image(model, image_path, output_dir)
#       2 def detect_from_image(model, image_path, output_dir="output"):
# ----> 3     output_path = Path(output_dir)
#       4     output_path.mkdir(parents=True, exist_ok=True)
#       6     results = model(image_path)
#
# NameError: name 'Path' is not defined

# %%
from pathlib import Path
from ultralytics import YOLO  # ✅ Import YOLO here!

def detect_from_image(model, image_path, output_dir="output"):
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)

    results = model.predict(image_path, save=True, save_txt=True, project=output_dir)
    print(f"Image prediction complete. Results saved to {output_dir}")

def detect_from_video(model, video_path, output_dir="output"):
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)

    results = model.predict(video_path, save=True, save_txt=True, project=output_dir)
    print(f"Video prediction complete. Results saved to {output_dir}")

# ✅ Load the trained model
trained_model = YOLO('D:/IIMS/sem 3/Computer Vision And Natural Language Processing/Python/Group_project/best_nepali_detection.pt')

# Paths
test_image = "D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets/test/test.jpeg"
test_video = "D:/IIMS/sem 3/Computer Vision And Natural Language Processing/datasets/test/test.mp4"

# Run detection
detect_from_image(trained_model, test_image)
detect_from_video(trained_model, test_video)
# Out:
# image 1/1 D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.jpeg: 640x640 3 number_plates, 2 cars, 6.3ms
# Speed: 2.8ms preprocess, 6.3ms inference, 49.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to output\predict
# 1 label saved to output\predict\labels
# Image prediction complete. Results saved to output
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 77.8ms
# video 1/1 (frame 2/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 6.1ms
# video 1/1 (frame 3/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 9.9ms
# video 1/1 (frame 4/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.2ms
# video 1/1 (frame 5/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.0ms
# video 1/1 (frame 6/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.2ms
# video 1/1 (frame 7/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.4ms
# video 1/1 (frame 8/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 6.8ms
# video 1/1 (frame 9/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.6ms
# video 1/1 (frame 10/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.9ms
# video 1/1 (frame 11/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.5ms
# video 1/1 (frame 12/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 6.1ms
# video 1/1 (frame 13/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.7ms
# video 1/1 (frame 14/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.3ms
# video 1/1 (frame 15/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.3ms
# video 1/1 (frame 16/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.0ms
# video 1/1 (frame 17/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.2ms
# video 1/1 (frame 18/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 scooter, 5.4ms
# video 1/1 (frame 19/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 20/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.1ms
# video 1/1 (frame 21/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 7.1ms
# video 1/1 (frame 22/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.6ms
# video 1/1 (frame 23/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.3ms
# video 1/1 (frame 24/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.7ms
# video 1/1 (frame 25/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.8ms
# video 1/1 (frame 26/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 7.2ms
# video 1/1 (frame 27/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.5ms
# video 1/1 (frame 28/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 29/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 6.2ms
# video 1/1 (frame 30/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.8ms
# video 1/1 (frame 31/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 32/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.9ms
# video 1/1 (frame 33/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.3ms
# video 1/1 (frame 34/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.2ms
# video 1/1 (frame 35/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 11.2ms
# video 1/1 (frame 36/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.5ms
# video 1/1 (frame 37/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.9ms
# video 1/1 (frame 38/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.5ms
# video 1/1 (frame 39/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.6ms
# video 1/1 (frame 40/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.9ms
# video 1/1 (frame 41/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 42/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 43/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 8.1ms
# video 1/1 (frame 44/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.2ms
# video 1/1 (frame 45/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 7.6ms
# video 1/1 (frame 46/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.4ms
# video 1/1 (frame 47/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.2ms
# video 1/1 (frame 48/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 6.8ms
# video 1/1 (frame 49/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 6.1ms
# video 1/1 (frame 50/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 5.6ms
# video 1/1 (frame 51/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 5.9ms
# video 1/1 (frame 52/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 5.5ms
# video 1/1 (frame 53/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.2ms
# video 1/1 (frame 54/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 55/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.3ms
# video 1/1 (frame 56/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 7.4ms
# video 1/1 (frame 57/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 58/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 59/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 60/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 7.5ms
# video 1/1 (frame 61/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.3ms
# video 1/1 (frame 62/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 63/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 64/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 8.6ms
# video 1/1 (frame 65/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.2ms
# video 1/1 (frame 66/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 9.0ms
# video 1/1 (frame 67/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 68/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 69/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.6ms
# video 1/1 (frame 70/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.6ms
# video 1/1 (frame 71/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 72/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.0ms
# video 1/1 (frame 73/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.9ms
# video 1/1 (frame 74/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.9ms
# video 1/1 (frame 75/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.4ms
# video 1/1 (frame 76/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.0ms
# video 1/1 (frame 77/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 78/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.1ms
# video 1/1 (frame 79/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.7ms
# video 1/1 (frame 80/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.4ms
# video 1/1 (frame 81/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.3ms
# video 1/1 (frame 82/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 83/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.0ms
# video 1/1 (frame 84/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.7ms
# video 1/1 (frame 85/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 86/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.3ms
# video 1/1 (frame 87/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.6ms
# video 1/1 (frame 88/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.1ms
# video 1/1 (frame 89/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.1ms
# video 1/1 (frame 90/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.9ms
# video 1/1 (frame 91/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.3ms
# video 1/1 (frame 92/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 93/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.1ms
# video 1/1 (frame 94/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 95/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.7ms
# video 1/1 (frame 96/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.5ms
# video 1/1 (frame 97/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.4ms
# video 1/1 (frame 98/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.9ms
# video 1/1 (frame 99/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.2ms
# video 1/1 (frame 100/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 10.0ms
# video 1/1 (frame 101/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.4ms
# video 1/1 (frame 102/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.7ms
# video 1/1 (frame 103/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 6.3ms
# video 1/1 (frame 104/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.3ms
# video 1/1 (frame 105/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 7.6ms
# video 1/1 (frame 106/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.7ms
# video 1/1 (frame 107/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.9ms
# video 1/1 (frame 108/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.4ms
# video 1/1 (frame 109/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.6ms
# video 1/1 (frame 110/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.6ms
# video 1/1 (frame 111/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.4ms
# video 1/1 (frame 112/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.2ms
# video 1/1 (frame 113/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.9ms
# video 1/1 (frame 114/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 7.1ms
# video 1/1 (frame 115/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 116/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.0ms
# video 1/1 (frame 117/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.3ms
# video 1/1 (frame 118/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.9ms
# video 1/1 (frame 119/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.8ms
# video 1/1 (frame 120/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.4ms
# video 1/1 (frame 121/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.6ms
# video 1/1 (frame 122/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.9ms
# video 1/1 (frame 123/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.4ms
# video 1/1 (frame 124/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.5ms
# video 1/1 (frame 125/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.3ms
# video 1/1 (frame 126/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.9ms
# video 1/1 (frame 127/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.9ms
# video 1/1 (frame 128/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.6ms
# video 1/1 (frame 129/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.8ms
# video 1/1 (frame 130/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.7ms
# video 1/1 (frame 131/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.3ms
# video 1/1 (frame 132/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.9ms
# video 1/1 (frame 133/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.3ms
# video 1/1 (frame 134/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.3ms
# video 1/1 (frame 135/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.4ms
# video 1/1 (frame 136/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.3ms
# video 1/1 (frame 137/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.6ms
# video 1/1 (frame 138/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.6ms
# video 1/1 (frame 139/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.6ms
# video 1/1 (frame 140/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.7ms
# video 1/1 (frame 141/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.3ms
# video 1/1 (frame 142/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.2ms
# video 1/1 (frame 143/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 1 bike, 6.4ms
# video 1/1 (frame 144/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 1 bike, 5.5ms
# video 1/1 (frame 145/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.5ms
# video 1/1 (frame 146/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.4ms
# video 1/1 (frame 147/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 10.1ms
# video 1/1 (frame 148/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.7ms
# video 1/1 (frame 149/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.5ms
# video 1/1 (frame 150/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.1ms
# video 1/1 (frame 151/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.2ms
# video 1/1 (frame 152/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 153/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.6ms
# video 1/1 (frame 154/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 155/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 156/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.1ms
# video 1/1 (frame 157/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.6ms
# video 1/1 (frame 158/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 159/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.6ms
# video 1/1 (frame 160/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.1ms
# video 1/1 (frame 161/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.8ms
# video 1/1 (frame 162/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 163/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 7.7ms
# video 1/1 (frame 164/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 10.3ms
# video 1/1 (frame 165/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.6ms
# video 1/1 (frame 166/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 167/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.0ms
# video 1/1 (frame 168/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.6ms
# video 1/1 (frame 169/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.0ms
# video 1/1 (frame 170/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.9ms
# video 1/1 (frame 171/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 10.9ms
# video 1/1 (frame 172/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 173/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 174/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.5ms
# video 1/1 (frame 175/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.4ms
# video 1/1 (frame 176/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 2 cars, 5.1ms
# video 1/1 (frame 177/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 2 cars, 6.5ms
# video 1/1 (frame 178/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 2 cars, 8.1ms
# video 1/1 (frame 179/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 2 cars, 7.6ms
# video 1/1 (frame 180/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 2 cars, 7.4ms
# video 1/1 (frame 181/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 2 cars, 7.5ms
# video 1/1 (frame 182/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 2 cars, 6.5ms
# video 1/1 (frame 183/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 2 cars, 5.5ms
# video 1/1 (frame 184/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (frame 185/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 9.8ms
# video 1/1 (frame 186/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.1ms
# video 1/1 (frame 187/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 10.4ms
# video 1/1 (frame 188/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 5.5ms
# video 1/1 (frame 189/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 5.3ms
# video 1/1 (frame 190/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 car, 10.3ms
# video 1/1 (frame 191/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.9ms
# video 1/1 (frame 192/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.3ms
# video 1/1 (frame 193/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.5ms
# video 1/1 (frame 194/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.3ms
# video 1/1 (frame 195/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.5ms
# video 1/1 (frame 196/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.3ms
# video 1/1 (frame 197/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 198/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.4ms
# video 1/1 (frame 199/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 200/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 201/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.2ms
# video 1/1 (frame 202/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 203/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.3ms
# video 1/1 (frame 204/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.5ms
# video 1/1 (frame 205/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.1ms
# video 1/1 (frame 206/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.5ms
# video 1/1 (frame 207/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.8ms
# video 1/1 (frame 208/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.7ms
# video 1/1 (frame 209/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.6ms
# video 1/1 (frame 210/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.0ms
# video 1/1 (frame 211/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 6.8ms
# video 1/1 (frame 212/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.9ms
# video 1/1 (frame 213/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 4.8ms
# video 1/1 (frame 214/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.7ms
# video 1/1 (frame 215/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.8ms
# video 1/1 (frame 216/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.1ms
# video 1/1 (frame 217/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.7ms
# video 1/1 (frame 218/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.4ms
# video 1/1 (frame 219/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.3ms
# video 1/1 (frame 220/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 5.5ms
# video 1/1 (frame 221/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.5ms
# video 1/1 (frame 222/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.3ms
# video 1/1 (frame 223/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.3ms
# video 1/1 (frame 224/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.0ms
# video 1/1 (frame 225/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 226/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.6ms
# video 1/1 (frame 227/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.1ms
# video 1/1 (frame 228/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.9ms
# video 1/1 (frame 229/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.4ms
# video 1/1 (frame 230/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 9.8ms
# video 1/1 (frame 231/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 22.0ms
# video 1/1 (frame 232/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 233/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.5ms
# video 1/1 (frame 234/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.3ms
# video 1/1 (frame 235/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 236/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.0ms
# video 1/1 (frame 237/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.3ms
# video 1/1 (frame 238/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.8ms
# video 1/1 (frame 239/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.1ms
# video 1/1 (frame 240/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.2ms
# video 1/1 (frame 241/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 2 cars, 5.2ms
# video 1/1 (frame 242/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.9ms
# video 1/1 (frame 243/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 car, 5.3ms
# video 1/1 (frame 244/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 car, 6.7ms
# video 1/1 (frame 245/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.3ms
# video 1/1 (frame 246/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.4ms
# video 1/1 (frame 247/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.1ms
# video 1/1 (frame 248/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 7.7ms
# video 1/1 (frame 249/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 7.0ms
# video 1/1 (frame 250/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 251/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 5.0ms
# video 1/1 (frame 252/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 6.4ms
# video 1/1 (frame 253/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 7.3ms
# video 1/1 (frame 254/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 7.0ms
# video 1/1 (frame 255/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.3ms
# video 1/1 (frame 256/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 7.2ms
# video 1/1 (frame 257/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 7.1ms
# video 1/1 (frame 258/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.2ms
# video 1/1 (frame 259/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 6.3ms
# video 1/1 (frame 260/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 car, 5.0ms
# video 1/1 (frame 261/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.2ms
# video 1/1 (frame 262/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 5.7ms
# video 1/1 (frame 263/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 5.2ms
# video 1/1 (frame 264/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 6.0ms
# video 1/1 (frame 265/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 6.1ms
# video 1/1 (frame 266/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.1ms
# video 1/1 (frame 267/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 6.0ms
# video 1/1 (frame 268/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.7ms
# video 1/1 (frame 269/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 6.2ms
# video 1/1 (frame 270/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 7.4ms
# video 1/1 (frame 271/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 5.3ms
# video 1/1 (frame 272/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 4 number_plates, 5.5ms
# video 1/1 (frame 273/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.5ms
# video 1/1 (frame 274/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.2ms
# video 1/1 (frame 275/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.3ms
# video 1/1 (frame 276/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 7.5ms
# video 1/1 (frame 277/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.0ms
# video 1/1 (frame 278/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 279/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.2ms
# video 1/1 (frame 280/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 6.5ms
# video 1/1 (frame 281/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 8.5ms
# video 1/1 (frame 282/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.0ms
# video 1/1 (frame 283/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 11.0ms
# video 1/1 (frame 284/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.2ms
# video 1/1 (frame 285/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.2ms
# video 1/1 (frame 286/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 287/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 288/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 289/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 4.9ms
# video 1/1 (frame 290/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 291/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.1ms
# video 1/1 (frame 292/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 293/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 294/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.5ms
# video 1/1 (frame 295/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 7.1ms
# video 1/1 (frame 296/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.6ms
# video 1/1 (frame 297/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.4ms
# video 1/1 (frame 298/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.5ms
# video 1/1 (frame 299/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 6.0ms
# video 1/1 (frame 300/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 4.9ms
# video 1/1 (frame 301/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.8ms
# video 1/1 (frame 302/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.1ms
# video 1/1 (frame 303/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.7ms
# video 1/1 (frame 304/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.0ms
# video 1/1 (frame 305/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 306/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 307/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 308/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 309/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 8.1ms
# video 1/1 (frame 310/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 311/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 312/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 313/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 314/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.3ms
# video 1/1 (frame 315/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.2ms
# video 1/1 (frame 316/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.2ms
# video 1/1 (frame 317/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 318/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 319/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 320/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 321/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 322/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 6.0ms
# video 1/1 (frame 323/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (frame 324/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 5.5ms
# video 1/1 (frame 325/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (frame 326/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 6.0ms
# video 1/1 (frame 327/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 (no detections), 5.2ms
# video 1/1 (frame 328/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 10.0ms
# video 1/1 (frame 329/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.2ms
# video 1/1 (frame 330/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.7ms
# video 1/1 (frame 331/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 12.9ms
# video 1/1 (frame 332/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 333/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.4ms
# video 1/1 (frame 334/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.8ms
# video 1/1 (frame 335/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.7ms
# video 1/1 (frame 336/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 10.8ms
# video 1/1 (frame 337/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 6.2ms
# video 1/1 (frame 338/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.6ms
# video 1/1 (frame 339/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 scooter, 5.6ms
# video 1/1 (frame 340/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 2 scooters, 5.9ms
# video 1/1 (frame 341/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.9ms
# video 1/1 (frame 342/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 scooter, 5.9ms
# video 1/1 (frame 343/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 scooters, 6.3ms
# video 1/1 (frame 344/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.9ms
# video 1/1 (frame 345/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.5ms
# video 1/1 (frame 346/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 8.0ms
# video 1/1 (frame 347/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 scooter, 5.6ms
# video 1/1 (frame 348/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 scooter, 5.2ms
# video 1/1 (frame 349/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 1 scooter, 5.4ms
# video 1/1 (frame 350/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.3ms
# video 1/1 (frame 351/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.3ms
# video 1/1 (frame 352/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 2 scooters, 5.3ms
# video 1/1 (frame 353/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.6ms
# video 1/1 (frame 354/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.2ms
# video 1/1 (frame 355/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 2 scooters, 5.2ms
# video 1/1 (frame 356/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.6ms
# video 1/1 (frame 357/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.2ms
# video 1/1 (frame 358/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.5ms
# video 1/1 (frame 359/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.4ms
# video 1/1 (frame 360/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.3ms
# video 1/1 (frame 361/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.5ms
# video 1/1 (frame 362/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.0ms
# video 1/1 (frame 363/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 7.9ms
# video 1/1 (frame 364/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.7ms
# video 1/1 (frame 365/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.8ms
# video 1/1 (frame 366/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 5.7ms
# video 1/1 (frame 367/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 1 scooter, 6.3ms
# video 1/1 (frame 368/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.3ms
# video 1/1 (frame 369/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 1 scooter, 6.9ms
# video 1/1 (frame 370/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 4.8ms
# video 1/1 (frame 371/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.8ms
# video 1/1 (frame 372/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 10.3ms
# video 1/1 (frame 373/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 3 number_plates, 5.1ms
# video 1/1 (frame 374/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.0ms
# video 1/1 (frame 375/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 5.4ms
# video 1/1 (frame 376/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.5ms
# video 1/1 (frame 377/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 1 number_plate, 5.9ms
# video 1/1 (frame 378/378) D:\IIMS\sem 3\Computer Vision And Natural Language Processing\datasets\test\test.mp4: 384x640 2 number_plates, 6.9ms
# Speed: 1.1ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to output\predict2
# 364 labels saved to output\predict2\labels
# Video prediction complete. Results saved to output
